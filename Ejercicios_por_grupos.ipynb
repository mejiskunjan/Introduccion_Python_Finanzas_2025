# %% [markdown]
# # 1
# Crea una lista con los números del 1 al 10 y elimina los múltiplos de 3.

# %%
# Aquí tu código

# %% [markdown]
# # 2
# Dada la lista [1, 2, 3, 4, 5], reemplaza el segundo y tercer elemento por [9, 8, 7]

# %%
lista = [1,2,3,4,5]
# Aquí tu código

# %% [markdown]
# # 3
# Ordena la lista `[5, 2, 9, 1]` de mayor a menor.

# %%
# Aquí tu código

# %% [markdown]
# # 4
# Crea una lista vacía y añade los cuadrados de los números del 1 al 5 usando un bucle.

# %%
# Aquí tu código

# %% [markdown]
# # 5
# Crea un diccionario con claves "nombre", "edad", "ciudad" y los valores que quieras. Modifica el valor de "edad".

# %%
# Aquí tu código

# %% [markdown]
# # 6
# Dado el diccionario {"a": 1, "b": 2}, añade una nueva clave "c" con valor 3.

# %%
dic = {'a':1,'b':2}
# Aquí tu código

# %% [markdown]
# # 7
# Crea un diccionario que almacene las notas de 3 asignaturas. Calcule la media con ese diccionario.

# %%
# Aquí tu código

# %% [markdown]
# # 8
# Crea una tupla con los números del 1 al 5. Imprime el tercer elemento.

# %%
# Aquí tu código

# %% [markdown]
# # 9
# Convierte la lista [10, 20, 30] en una tupla y accede al último elemento.

# %%
# Aquí tu código

# %% [markdown]
# # 10
# Crea una tupla que contenga una lista como elemento. Modifica la lista dentro de la tupla.

# %%
# Aquí tu código

# %% [markdown]
# # 11
# Imprime los números del 1 al 10 usando un bucle for

# %%
# Aquí tu código

# %% [markdown]
# # 12
# Imprime los números del 10 al 1 usando un bucle while.

# %%
# Aquí tu código

# %% [markdown]
# # 13
# Usa un bucle para sumar los números del 1 al 100.

# %%
# Aquí tu código

# %% [markdown]
# # 14
# Crea una función que reciba un número y devuelva su factorial.

# %%
# Aquí tu código

# %% [markdown]
# # 15
# Crea una función que reciba una lista y devuelva otra con los elementos duplicados.

# %%
# Aquí tu codigo

# %% [markdown]
# # 16
# Crea una función que reciba una cadena y devuelva la misma cadena invertida.

# %%
# Aquí tu codigo
