# %% [markdown]
# ## RETO 1
#
# En este reto, que puedes afrontar solo o en pareja, vamos a poner a prueba las 5 horas de programación que llevamos.

# %% [markdown]
# Un mago tiene una lista de objetos mágicos con distintos poderes llamada inventario. Cada objeto tiene un nombre y un valor numérico de poder. El mago quiere saber:
#
# - Cuáles objetos tienen poder suficiente para una misión (mayor o igual a 50).
#
# - Cuál es el objeto más poderoso.
#
# - Cuántos objetos hay por encima de cierto umbral.
#
# - Crear una nueva lista con los nombres de los objetos válidos.

# %%
inventario = [
    ["Varita de Roble", 45],
    ["Amuleto Solar", 60],
    ["Piedra del Tiempo", 30],
    ["Capa de Invisibilidad", 80],
    ["Libro de Sombras", 55],
    ["Anillo de Fuego", 25],
    ["Orbe de Hielo", 70],
    ["Espada de Luz", 90],
    ["Escudo de Dragón", 40],
    ["Botas del Viento", 35],
    ["Corona de Cenizas", 65],
    ["Pergamino del Caos", 50],
    ["Lágrima de Fénix", 20],
    ["Cristal del Vacío", 75],
    ["Guantes de Titanio", 38],
    ["Túnica del Eclipse", 58],
    ["Reloj del Destino", 42],
    ["Cuchilla de Sombras", 85],
    ["Medallón del Alba", 33],
    ["Cetro del Juicio", 95]
]

# %%
# Aquí tu código

# %% [markdown]
# ### Extra
#
# - Ordenar los objetos por poder.
# - Usar `input()` para establecer una horquilla de poder (por ejemplo entre 40 y 60) para clasificar.
# - Establecer 3 horquillas de poder y agregar a cada objeto, al final, 'Debil', 'Normal', 'Poderoso' en función de la orquilla. (Puedes usar input o ponerlo a mano en el código)

# %%
# Aquí tu código
